# %%
import numpy as np
import polars as pd
from pathlib import Path

# %%
DATA_PATH = Path("../data")

# %%
repna_1 = pd.read_csv(DATA_PATH / "raw" / "reporte-repna-1.csv")
repna_2 = pd.read_csv(DATA_PATH / "raw" / "reporte-repna-2.csv")

# %%
repna_2.height
# Out:
# 6087

# %%
repna_2
# Out:
# shape: (6_087, 14)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Titular   ┆ Título    ┆ Uso      ┆ Autoridad ┆ … ┆ Número de ┆ Volumen   ┆ Número de ┆ Superfici │
# │ ---       ┆ ---       ┆ ---      ┆ que emite ┆   ┆ anexos de ┆ de        ┆ anexos de ┆ e (m2):   │
# │ str       ┆ str       ┆ str      ┆ el acto   ┆   ┆ descarga: ┆ descarga  ┆ zonas     ┆ ---       │
# │           ┆           ┆          ┆ ---       ┆   ┆ ---       ┆ (m3/día): ┆ fede…     ┆ f64       │
# │           ┆           ┆          ┆ str       ┆   ┆ i64       ┆ ---       ┆ ---       ┆           │
# │           ┆           ┆          ┆           ┆   ┆           ┆ f64       ┆ i64       ┆           │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ AGROPECUA ┆ 827758    ┆ AGRICOLA ┆ ORGANISMO ┆ … ┆ 0         ┆ 0.0       ┆ 0         ┆ 0.0       │
# ...

# %%
pd.dataframe.frame.DataFrame.height
